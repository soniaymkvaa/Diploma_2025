# %% [markdown]
# **Hierarchical clustering with Gower's Distance**

# %% [markdown]
# *Imports:*

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns
import ace_tools_open as tools
from sklearn.manifold import TSNE
import gower
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram

# %% [markdown]
# *Downloaing the dataset:*

# %%
df = pd.read_excel("sofiia_diploma_flights_final.xlsx")
df = df.drop(columns=['ID', 'ICAO Departure Airport', 'ICAO Arrival Airport', 'Currency', 'Aircraft'])

df['Month'] = df['Date'].dt.month
df['DayOfWeek'] = df['Date'].dt.dayofweek
df = df.drop(columns=['Date'])
print(df.head())
# Out:
#    Route  Net Price  Gross Price  Profit         Departure City  \
# 0  there      38955        40876    1921                 Warsaw
# 1   back      38955        40876    1921                   Sion
# 2  there      39941        40755     814      London (Northolt)
# 3   back      39941        40755     814                 Geneva
# 4  there      64197        65362    1165  Dubai (World Central)
#
#         Arrival City  Num of Pax     Aircraft Type  Distance Trip Type  Month  \
# 0               Sion           4           Midsize   1198.21  Business      5
# 1             Warsaw           4           Midsize   1198.21  Business      5
# 2             Geneva           2             Light    762.27  Business      2
# 3  London (Northolt)           2             Light    762.27  Business      2
# 4             Jeddah           3  Ultra Long Range   1677.18  Business      6
#
#    DayOfWeek
# 0          6
# 1          4
# 2          3
# 3          2
# 4          2

# %% [markdown]
# *Transformation of categorical features and data scaling*

# %%
regions = {
    "asia": ['Hanoi', 'Tashkent', 'Almaty', 'Dushanbe', 'Yerevan', 'Addis Ababa', 'Dharavandhoo', 'Ganja'],
    "middle_east": ['Ercan', 'Riyadh', 'Jeddah', 'Dubai (World Central)'],
    "south_europe": ['Ponta Delgada', 'Cascais', 'Lisbon', 'Málaga', 'Alicante', 'Valencia', 'Ibiza', 'Palma de Mallorca', 
                     'Barcelona', 'Olbia', 'Rome (Ciampino)', 'Naples', 'Catania', 'Malta', 'Corfu', 'Thessaloniki', 
                     'Mykonos', 'Athens', 'Bodrum', 'Istanbul (Istanbul Airport)', 'Istanbul (Atatürk)', 'Dalaman', 
                     'Antalya', 'Gazipaşa', 'Paphos', 'Larnaca'],
    "east_europe": ['Warsaw', 'Kraków', 'Rzeszów', 'Košice', 'Suceava', 'Chișinău', 'Belgrade', 'Bucharest (Henri Coandă)', 
                    'Bucharest (Băneasa)', 'Sofia'],
    "north_europe": ['Reykjavik', 'Oslo', 'Tallinn', 'Riga', 'Copenhagen'],
    "center_europe": ['Berlin', 'Karlovy Vary', 'Prague', 'Munich', 'Vienna', 'Budapest', 'Innsbruck', 'Bolzano', 'Venice', 
                      'Florence', 'Tivat'],
    "west_europe": ['London (Northolt)', 'London (Biggin Hill)', 'London (Gatwick)', 'Amsterdam', 'Bremen', 'Liège', 
                    'Karlsruhe/Baden-Baden', 'Paris (Le Bourget)', 'Deauville', 'Zurich', 'Buochs', 'Sion', 'Geneva', 'Lugano', 
                    'Samedan', 'Chambéry', 'Courchevel Altiport', 'Courchevel', 'Milan (Malpensa)', 'Milan (Linate)', 'Genoa', 
                    'Monte Carlo', 'Nice', 'Cannes', 'Saint-Tropez', 'Toulon', 'Girona', 'Toulouse', 'San Sebastián'],
    "africa": ['Marrakesh'],
    "north_america": ['Carlsbad', 'San Francisco', 'Grand Cayman', 'Los Angeles', 'Toluca', 'Cancún', 'Sarasota', 'Van Nuys', 
                      'Page', 'Nassau']
}

continent_groups = {
    'isAsia': regions['asia'],
    'isMiddleEast': regions['middle_east'],
    'isEurope': regions['south_europe'] + regions['east_europe'] + regions['north_europe'] + regions['center_europe'] + regions['west_europe'],
    'isAfrica': regions['africa'],
    'isAmerica': regions['north_america']
}

def assign_region_flags(df, city_column_prefix):
    for region_name, city_list in continent_groups.items():
        col_name = f"{region_name}_{city_column_prefix}"
        df[col_name] = df[city_column_prefix].isin(city_list).astype(int)
    return df

df = assign_region_flags(df, 'Departure City')
df = assign_region_flags(df, 'Arrival City')



df['Trip Type'] = df['Trip Type'].map({'Business': 0, 'Vacation': 1})
df['Route'] = df['Route'].map({'there': 0, 'back': 1})
df = df.drop(columns=['Departure City', 'Arrival City'])


aircraft_mapping = {
    "Turboprob": 0,
    "Entry Level": 1,
    "Light": 2,
    "Super Light": 3,
    "Midsize": 4,
    "Super Midsize": 5,
    "Heavy": 6,
    "Ultra Long Range": 7,
    "VIP Airliner": 8
}
df['Aircraft Type'] = df['Aircraft Type'].map(aircraft_mapping)


num_cols = ['Net Price', 'Gross Price', 'Profit', 'Distance']
descrete_cols = ['Aircraft Type', 'Trip Type', 'Route', 'Num of Pax', 'Month', 'DayOfWeek']



scaler_standard = StandardScaler()
scaler_minmax = MinMaxScaler(feature_range=(-1, 1))

df_mixed = df.copy()
df_mixed[num_cols] = scaler_standard.fit_transform(df[num_cols])
df_mixed[descrete_cols] = scaler_minmax.fit_transform(df[descrete_cols])

print("Original data:")
print(df.head(), "\n")

print("Scaled data:")
print(df_mixed.head())
# Out:
# Original data:
#    Route  Net Price  Gross Price  Profit  Num of Pax  Aircraft Type  Distance  \
# 0      0      38955        40876    1921           4              4   1198.21
# 1      1      38955        40876    1921           4              4   1198.21
# 2      0      39941        40755     814           2              2    762.27
# 3      1      39941        40755     814           2              2    762.27
# 4      0      64197        65362    1165           3              7   1677.18
#
#    Trip Type  Month  DayOfWeek  isAsia_Departure City  \
# 0          0      5          6                      0
# 1          0      5          4                      0
# 2          0      2          3                      0
# 3          0      2          2                      0
# 4          0      6          2                      0
#
#    isMiddleEast_Departure City  isEurope_Departure City  \
# 0                            0                        1
# 1                            0                        1
# 2                            0                        1
# 3                            0                        1
# 4                            1                        0
#
#    isAfrica_Departure City  isAmerica_Departure City  isAsia_Arrival City  \
# 0                        0                         0                    0
# 1                        0                         0                    0
# 2                        0                         0                    0
# 3                        0                         0                    0
# 4                        0                         0                    0
#
#    isMiddleEast_Arrival City  isEurope_Arrival City  isAfrica_Arrival City  \
# 0                          0                      1                      0
# 1                          0                      1                      0
# 2                          0                      1                      0
# 3                          0                      1                      0
# 4                          1                      0                      0
#
#    isAmerica_Arrival City
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
#
# Scaled data:
#    Route  Net Price  Gross Price    Profit  Num of Pax  Aircraft Type  \
# 0   -1.0   0.059625     0.080590  1.197013    0.333333           0.00
# 1    1.0   0.059625     0.080590  1.197013    0.333333           0.00
# 2   -1.0   0.092315     0.076618 -0.820809   -1.000000          -0.50
# 3    1.0   0.092315     0.076618 -0.820809   -1.000000          -0.50
# 4   -1.0   0.896498     0.884353 -0.181012   -0.333333           0.75
#
#    Distance  Trip Type     Month  DayOfWeek  isAsia_Departure City  \
# 0 -0.276832       -1.0 -0.111111   1.000000                      0
# 1 -0.276832       -1.0 -0.111111   0.333333                      0
# 2 -0.560632       -1.0 -0.777778   0.000000                      0
# 3 -0.560632       -1.0 -0.777778  -0.333333                      0
# 4  0.034981       -1.0  0.111111  -0.333333                      0
#
#    isMiddleEast_Departure City  isEurope_Departure City  \
# 0                            0                        1
# 1                            0                        1
# 2                            0                        1
# 3                            0                        1
# 4                            1                        0
#
#    isAfrica_Departure City  isAmerica_Departure City  isAsia_Arrival City  \
# 0                        0                         0                    0
# 1                        0                         0                    0
# 2                        0                         0                    0
# 3                        0                         0                    0
# 4                        0                         0                    0
#
#    isMiddleEast_Arrival City  isEurope_Arrival City  isAfrica_Arrival City  \
# 0                          0                      1                      0
# 1                          0                      1                      0
# 2                          0                      1                      0
# 3                          0                      1                      0
# 4                          1                      0                      0
#
#    isAmerica_Arrival City
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %% [markdown]
# *Silhouette Score:*

# %%
selected_features = ["Trip Type", "Distance", "Aircraft Type", "Route"]

X = df_mixed[selected_features]

feature_sets = {"final": selected_features}

def evaluate_hierarchical_gower(features, cluster_range=(2, 15)):
    results = []
    X_subset = df_mixed[features]

    #Gower distance matrix
    distance_matrix = gower.gower_matrix(X_subset)

    for n_clusters in range(cluster_range[0], cluster_range[1] + 1):
        Z = linkage(distance_matrix, method='ward')
        labels = fcluster(Z, t=n_clusters, criterion='maxclust')

        sil_score = silhouette_score(distance_matrix, labels, metric='precomputed')

        results.append({
            "Feature Set": ", ".join(features),
            "Num Clusters": n_clusters,
            "Silhouette Score": sil_score
        })

    return results

all_results = []
for name, features in feature_sets.items():
    all_results.extend(evaluate_hierarchical_gower(features))

results_df = pd.DataFrame(all_results)

for feature_set in results_df["Feature Set"].unique():
    subset = results_df[results_df["Feature Set"] == feature_set]

    plt.figure(figsize=(6, 4))
    plt.plot(subset["Num Clusters"], subset["Silhouette Score"], marker='o', linestyle='-')
    plt.xlabel("Number of clusters")
    plt.ylabel("Silhouette Score")
    plt.title(f"Silhouette Score for {feature_set}")
    plt.grid(True)
    plt.show()
# Out:
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/2691402284.py:15: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix, method='ward')

# %% [markdown]
# *Dendrogram:*

# %%
selected_features = ["Trip Type", "Distance", "Aircraft Type", "Route"]
X = df_mixed[features]
plt.figure(figsize=(12, 6))
distance_matrix_full = gower.gower_matrix(X)
Z = linkage(distance_matrix_full, method='ward')

num_clusters = 4
labels = fcluster(Z, num_clusters, criterion='maxclust')
threshold = (Z[-num_clusters + 1, 2] + Z[-num_clusters, 2]) / 2

plt.figure(figsize=(12, 6))
dendrogram(Z, color_threshold=threshold)


plt.title('Dendrogram')
plt.xlabel('Observation')
plt.ylabel('Distance')
plt.show()
# Out:
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/1874151444.py:5: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(distance_matrix_full, method='ward')

# %% [markdown]
# *Clusters characteristics:*

# %%
optimal_k = 4
df_mixed["Cluster"] = fcluster(Z, t=optimal_k, criterion='maxclust')

cluster_summary = df_mixed.groupby("Cluster")[selected_features].agg(["min", "max", "mean", "median"])
cluster_counts = df_mixed["Cluster"].value_counts().sort_index()
cluster_summary["Count"] = cluster_counts

tools.display_dataframe_to_user(name="Hierarchical Cluster Characteristics", dataframe=cluster_summary)
# Out:
# Hierarchical Cluster Characteristics
# <table id="itables_d6c01372_c8fb_46a7_b8d9_167da8b49f2a" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">Trip Type</th>
#       <th colspan="4" halign="left">Distance</th>
#       <th colspan="4" halign="left">Aircraft Type</th>
#       <th colspan="4" halign="left">Route</th>
#       <th>Count</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>Cluster</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_d6c01372_c8fb_46a7_b8d9_167da8b49f2a:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[1, -1.0, -1.0, -1.0, -1.0, -0.933348, 4.657594, 0.073093, -0.214264, -1.0, 1.0, -0.016949, 0.0, -1.0, -1.0, -1.0, -1.0, 118], [2, 1.0, 1.0, 1.0, 1.0, -1.048107, 4.304663, -0.041194, -0.237094, -1.0, 1.0, -0.134409, 0.0, -1.0, -1.0, -1.0, -1.0, 93], [3, 1.0, 1.0, 1.0, 1.0, -1.048107, 1.296563, -0.330815, -0.669266, -1.0, 0.5, -0.166667, 0.0, 1.0, 1.0, 1.0, 1.0, 15], [4, -1.0, -1.0, -1.0, -1.0, -0.912444, 3.71666, 0.007321, -0.360122, -0.75, 0.75, -0.130435, 0.0, 1.0, 1.0, 1.0, 1.0, 23]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# *Visualization of clasters in 2D using t-SNE*

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(X)

df_mixed["t-SNE_1"] = X_tsne[:, 0]
df_mixed["t-SNE_2"] = X_tsne[:, 1]

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_mixed["t-SNE_1"], y=df_mixed["t-SNE_2"], hue=df_mixed["Cluster"], palette="viridis", s=50)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("Clusters in the t-SNE")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# *Characteristics of financial features for each cluster:*

# %%
financial_features = ["Net Price", "Gross Price", "Profit"]
cluster_financial_summary = df_mixed.groupby("Cluster")[financial_features].agg(["min", "max", "mean", "median"])

tools.display_dataframe_to_user(name="Cluster Financial Characteristics", dataframe=cluster_financial_summary)
# Out:
# Cluster Financial Characteristics
# <table id="itables_77a626ed_6cda_4ccd_9146_71bc63b110a2" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">Net Price</th>
#       <th colspan="4" halign="left">Gross Price</th>
#       <th colspan="4" halign="left">Profit</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>median</th>
#     </tr>
#     <tr>
#       <th>Cluster</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_77a626ed_6cda_4ccd_9146_71bc63b110a2:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [[1, -0.995899, 4.351575, 0.015463, -0.316458, -1.010987, 4.334076, 0.016702, -0.301432, -1.393163, 2.208657, 0.077298, -0.031544], [2, -1.199266, 4.576989, -0.134598, -0.330664, -1.212469, 4.570091, -0.137161, -0.3315, -1.393163, 2.181316, -0.216429, -0.407037], [3, -1.168267, 1.788108, 0.125745, -0.274601, -1.181777, 1.790926, 0.12469, -0.290994, -1.393163, 1.217063, 0.010623, -0.100809], [4, -0.781824, 3.172387, 0.382905, -0.160186, -0.788791, 3.145139, 0.387603, -0.164058, -1.291087, 2.040961, 0.471624, 0.23276]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
financial_means = {
    "Net Price": 37156.582329,
    "Gross Price": 38420.887550,
    "Profit": 1264.305221
}

financial_stds = {
    "Net Price": 30223.025387,
    "Gross Price": 30525.547796,
    "Profit": 549.716403
}

#X = X0 * st.d. + mean
df_unscaled = df_mixed.copy()
for feature in financial_features:
    df_unscaled[feature] = df_mixed[feature] * financial_stds[feature] + financial_means[feature]

cluster_financial_stats = df_unscaled.groupby("Cluster")[financial_features].agg(["min", "max", "median", "mean"])


for feature in financial_features:
    plt.figure(figsize=(8, 6))
    clusters = df_unscaled["Cluster"].unique()

    for cluster in clusters:
        cluster_values = df_unscaled[df_unscaled["Cluster"] == cluster][feature]
        plt.scatter([cluster] * len(cluster_values), cluster_values, color='blue', alpha=0.5, s=10, label="Values" if cluster == 0 else "")

    medians = cluster_financial_stats[(feature, "median")]
    means = cluster_financial_stats[(feature, "mean")]


    for cluster in clusters:
        plt.scatter(cluster, medians[cluster], color='orange', marker='s', s=50, label='Median' if cluster == 0 else "")
        plt.scatter(cluster, means[cluster], color='purple', marker='D', s=50, label='Mean' if cluster == 0 else "")

    plt.title(f"{feature}")
    plt.xlabel("Cluster")
    plt.ylabel(feature)
    plt.legend()
    plt.show()
# Out:
# /var/folders/4j/bz5mm8l939g1jyszh1q_8_nc0000gn/T/ipykernel_29775/394839741.py:40: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
